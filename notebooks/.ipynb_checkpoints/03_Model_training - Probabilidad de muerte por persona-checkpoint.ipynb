# %% [markdown]
# # Prática Machine Learning - CUNEF
#
# ## Alumno: Amadeo Gustavo Ancarani
#
# ### Definición del Script: 03_Model_training
#
# Con los datos tratados anteriormente, vamos a realizar las estimaciones de los modelos y seleccionar aquel modelo que en el conjunto de métricas disponibles, genere una mejor clasificación.
#
# ### Explicación de las métricas aplicadas para la selección del mejor modelo
#
# En este caso particular nos interesa se intenta predecir si una persona involucrada en un accidente fallecería.
#
# Podríamos predecir que nadie fallecería ya que solo el 1,62% de las personas registradas han sufrido este destino. Esto es bastante ineficiente porque en el momento que se genera una muerte, los costos de no haber apartado el dinero para realizar los correspondientes pagos a la familia afectada, son muy grandes. Sería más eficiente estimar una probabilidad de quienes son más propensos a fallecer dadas las caracteristicas del accidente, del coche y de la persona afectada.
#
# Sin embargo, ningún modelo de Machine Learning es perfecto. Esto quiere decir que:
#
# * habrá accidentados con los que estimaremos un fallecimiento porque el modelo ha predicho que sucedería y en realidad no sucede (False Positive (FP), Positivos Falsos).
#
# * habrá también accidentados con los que no estimaremos un fallecimiento porque el modelo ha predicho que no sucedería y que en realidad si sucedió (False Negative (FN), Negativos Falsos).
#
# El modelo de Machine Learning también acertará (esperemos que mucho). A efectos prácticos esto significa que:
#
# * habrá accidentados con los que estimaremos un fallecimiento porque el modelo ha predicho que sucedería y sucede realmente (True Positive (TP), Verdaderos Positivos).
#
# * habrá también accidentados con los que no estimaremos un fallecimiento porque el modelo ha predicho que no sucedería y no sucedio (True Negative (TN), Verdaderos Negativos).
#
# #### Confusion Matrix (Matriz de Confusión)
#
# Vamos a explicar como funciona la matriz de confusión. En este ejemplo, estimamos 100 accidentados fallecidos y 80 de ellos no han resultado muertos y 20 de ellos sí.
#
# Nuestro modelo (en el ejemplo) dependiendo de qué métrica usemos podría parecer que es mejor de lo que es.
#
# Hemos utilizado como valores de la clasificación binaria:
#
# * 0: no ha fallecido
#
# * 1: sí ha fallecido
#
# **De esta matriz se derivan las métricas: precision, recall, f1 y accuracy entre otras.**
#
# Matriz de Confusión
#
# ![MDC](../images/matriz_de_confusion.png)
#
# En la matriz de confusión de la izquierda podéis ver los valores para este ejemplo. En la matriz de confusión de la derecha, los nombres genéricos cuando usamos la nomenclatura inglesa: True Negative [TN], True Positive [TP], False Positive [FP], False Negative [FN].
#
# Truco: para recordar fácilmente la matriz de confusión:
#
# * Positivo (Positive) o Negativo (Negative): se refiere a la predicción. Si el modelo predice 1 entonces será positivo, y se predice 0 será negativo.
#
# * Verdadero (True) o Falso (False): se refiere si la predicción es correcta o no.
#
# #### Precision (Precisión)
#
# Con la métrica de precisión podemos medir la **calidad** del modelo de machine learning en tareas de clasificación. En el ejemplo, se refiere a que la precisión es la respuesta a la pregunta ¿qué porcentaje de los accidentados estimados como fallecidos, han sufrido este destino?
#
# Para calcular la precisión usaremos la siguiente fórmula:
#
# ![Precition](../images/precition3.png)
#
#
# En nuestro ejemplo, siguiendo los datos de la matriz de confusión, tenemos que:
#
# ![Precition2](../images/precition2.png)
#
# Es decir, que sólo un 33% de las personas estimadas fallecidas, han muerto. Esto significa que el modelo del ejemplo se equivocará un 66% de las veces cuando prediga.
#
# #### Recall (Exhaustividad)
#
# La métrica de exhaustividad nos va a informar sobre la **cantidad** que el modelo de machine learning es capaz de identificar. En el ejemplo, se refiere a que la exhaustividad (recall) es la respuesta a la pregunta ¿qué porcentaje de los fallecidos somos capaces de identificar?
#
# Para calcular la exhaustividad (recall) usaremos la siguiente fórmula:
#
# ![Recall](../images/recall.png)
#
# En el ejemplo, siguiendo los datos de la matriz de confusión, tenemos que:
#
# ![Recall2](../images/recall2.png)
#
# Es decir, el modelo sólo es capaz de identificar un 25% de los accidentados fallecidos. Esto significa que el modelo del ejemplo sólo es capaz de identificar 1 de cada 4 muertes.
#
# #### F1
#
# El valor F1 se utiliza para combinar las medidas de precision y recall en un sólo valor. Esto es práctico porque hace más fácil el poder comparar el rendimiento combinado de la precisión y la exhaustividad entre varias soluciones.
#
# F1 se calcula haciendo la media armónica entre la precisión y la exhaustividad:
#
# ![F1](../images/f1.png)
#
# En el ejemplo de marketing, combinando precision y recall en F1 nos quedaría:
#
# ![F12](../images/f12.png)
#
# El valor F1 asume que nos importa de igual forma la precisión y la exhaustividad.
#
# #### Accuracy (Exactitud)
#
# La exactitud (accuracy) mide el porcentaje de casos que el modelo ha acertado. Esta es una de las métricas más usadas y favoritas … que te recomiendo evitar! El problema con la exactitud es que nos puede llevar al engaño, es decir, puede hacer que un modelo malo (como el del ejemplo) parezca que es mucho mejor de lo que es.
#
# ![accuracy](../images/accuracy.png)
#
# La exactitud del ejemplo de marketing sería:
#
# ![accuracy2](../images/accuracy2.png)
#
# Es decir, el modelo acierta el 75% de las veces. Como ves, la exactitud es una métrica muy engañosa. De hecho, si tuviésemos un modelo que siempre predijera que el accidentado no fallece, su accuracy sería del 80%.
#
# Peligro: la métrica accuracy (exactitud) no funciona bien cuando las clases están desbalanceadas como es en este caso. La mayoría no fallece, así que es muy fácil acertar diciendo que no va a suceder. Para problemas con clases desbalanceadas es mucho mejor usar precision, recall y F1. Estas métricas dan una mejor idea de la calidad del modelo.
#
# #### Curva ROC
#
# Para los modelos de clasificación obtenidos a partir de una probabilidad se suelen usar las curvas ROC. Una curva ROC (acrónimo de Receiver Operating Characteristic, o Característica Operativa del Receptor) es una representación gráfica de la sensitivity (TPR) frente a la specificity (TNR) para un sistema clasificador binario según se varía el umbral de discriminación.
#
# La curva ROC se puede usar para generar estadísticos que resumen el rendimiento (o la efectividad, en su más amplio sentido) del clasificador. A continuación se proporcionan algunos:
#
# * El punto de inserción de la curva ROC con la línea convexa a la línea de discriminación.
#
# * El área entre la curva ROC y la línea de convexo-paralela discriminación.
# * El área bajo la curva ROC, llamada comúnmente AUC (area under curve).
#
# El indicador más utilizado en muchos contextos es el **área bajo la curva ROC o AUC.** Este índice se puede interpretar como la probabilidad de que un clasificador ordenará o puntuará una instancia positiva elegida aleatoriamente más alta que una negativa.
#
# En la figura abajo se muestran tres ejemplos de curvas ROC. La gráfica de la izquierda es la curva de un modelo perfecto, la del medio es la de un caso real con una `AUC = 0.8` y la de la derecha es la gráfico de un modelo no informativo.
#
# ![roc](../images/roc.png)
#
# #### Ganancia y elevación (Gain and Lift Charts)
#
# La **ganancia** y la **elevación** son medida de la efectividad de un modelo de clasificación calculado como la relación entre los resultados obtenidos con y sin el modelo. Los gráficos de ganancia y elevación son ayudas visuales para evaluar el rendimiento de los modelos de clasificación. Sin embargo, en contraste con la matriz de confusión que evalúa los modelos en toda la población, los gráficos de ganancia o elevación evalúan el modelo en una porción de la población.
#
# Para crear estos gráficos es necesario crear un ranking basado en la creabilidad de la clasificación (previsión) hecha por el modelo.
#
# En siguiente imagen se muestra un ejemplo de como obtener los puntos de las curvas de ganancia y elevación, y sus correspondientes gráficos.
#
# ![gain](../images/gain.png)
#
# Igual que las curvas ROC, se busca el mayor AUC en las curvas de ganancia. Mientras que para los gráficos de elevación el modelo perfecto es el que la diferencia entre la línea azul y roja es nula. En otras palabras queremos una AUC mínima del gráfico de elevación. En las siguientes imágenes se muestra la forma de interpretar las curvas de Lift y Gain acumulado, respectivamente.
#
# ![lift](../images/lift.png)
#
# ![gain2](../images/gain2.png)
#
# ![resumen](../images/resumen.png)

# %% [markdown]
# # 0. Importar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings("ignore")
from sklearn import tree
from sklearn.pipeline import Pipeline

from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, \
                            silhouette_score, recall_score, precision_score, make_scorer, \
                            roc_auc_score, f1_score, precision_recall_curve

from sklearn.metrics import accuracy_score, roc_auc_score, \
                            classification_report, confusion_matrix


from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import pickle
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from imblearn.over_sampling import SMOTE
import re

from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier
import random
import scikitplot as skplt

# %% [markdown]
# # 1. Importar Datos

# %%
train = pd.read_csv("../data/train_data_personal_prob.csv",low_memory=False)
train.set_index(['Unnamed: 0'], inplace=True)
train.index.names = ['']

test = pd.read_csv("../data/test_data_personal_prob.csv",low_memory=False)
test.set_index(['Unnamed: 0'], inplace=True)
test.index.names = ['']

# %%
train.shape
# Out:
# (4081586, 23)

# %%
test.shape
# Out:
# (1360690, 23)

# %% [markdown]
# # 2. Separo a mis datasets en variables exógenas (X) y objetivo (y)

# %%
ytrain = train['C_SEV']
xtrain = train.drop(columns=['C_SEV'])

ytest = test['C_SEV']
xtest = test.drop(columns=['C_SEV'])

# %%
xtrain.head()
# Out:
#          C_YEAR    C_VEHS    C_CONF    C_RCFG    C_WTHR    C_RSUR    V_TYPE  \
#
# 4850824    2011  0.013298  0.025305  0.027714  0.013715  0.014277  0.014307
# 3179371    2006  0.012907  0.013763  0.011817  0.015883  0.019240  0.014307
# 5330174    2013  0.012907  0.003711  0.027714  0.015883  0.016904  0.014307
# 4880251    2011  0.012907  0.003711  0.027714  0.015883  0.016904  0.014307
# 3039624    2006  0.012907  0.003711  0.009720  0.015883  0.016904  0.014307
#
#             P_SEX  P_AGE     P_PSN  ...  V_YEAR_NNNN  V_YEAR_UUUU  P_AGE_UU  \
#                                     ...
# 4850824  0.020431   31.0  0.015287  ...            0            0         0
# 3179371  0.020431   44.0  0.015287  ...            0            0         0
# 5330174  0.020431   18.0  0.015287  ...            0            0         0
# 4880251  0.012568   27.0  0.015287  ...            0            0         0
# 3039624  0.012568   36.0  0.015287  ...            0            0         0
#
# ...

# %%
xtest.head()
# Out:
#          C_YEAR    C_VEHS    C_CONF    C_RCFG    C_WTHR    C_RSUR    V_TYPE  \
#
# 87310      1999  0.012907  0.012065  0.009720  0.015883  0.014277  0.014307
# 2333390    2004  0.012907  0.018530  0.027714  0.020966  0.016904  0.014307
# 1485833    2002  0.013298  0.003711  0.011817  0.015883  0.016904  0.014307
# 1155103    2001  0.012907  0.003711  0.027714  0.015883  0.016904  0.014307
# 3970807    2009  0.012907  0.013763  0.011817  0.015883  0.019240  0.014307
#
#             P_SEX  P_AGE     P_PSN  ...  V_YEAR_NNNN  V_YEAR_UUUU  P_AGE_UU  \
#                                     ...
# 87310    0.012568    3.0  0.015287  ...            0            0         0
# 2333390  0.020431   43.0  0.015287  ...            0            0         0
# 1485833  0.012568   25.0  0.015287  ...            0            0         0
# 1155103  0.020431   46.0  0.015287  ...            0            0         0
# 3970807  0.020431   45.0  0.015287  ...            0            0         0
#
# ...

# %% [markdown]
# # 3. Observo las distribuciones de los fallecidos

# %%
ytrain.value_counts()/len(ytrain)
# Out:
# 0    0.983254
# 1    0.016746
# Name: C_SEV, dtype: float64

# %%
ytest.value_counts()/len(ytest)
# Out:
# 0    0.983176
# 1    0.016824
# Name: C_SEV, dtype: float64

# %% [markdown]
# # 4. Defino la función para obtener las métricas a utilizar para evaluar los modelos.

# %%
def evaluate_model(ytest, ypred, ypred_proba = None):
    if ypred_proba is not None:
        print('ROC-AUC score of the model: {}'.format(roc_auc_score(ytest, ypred_proba[:, 1])))
    print('')
    print('Accuracy of the model: {}\n'.format(accuracy_score(ytest, ypred)))
    
    score = f1_score(ytest, ypred)
    print('F-Score: %.5f' % score)
    print('')
    print('Classification report: \n{}\n'.format(classification_report(ytest, ypred)))
    #print('Confusion matrix: \n{}\n'.format(confusion_matrix(ytest, ypred)))
    
    
    print('Confusion matrix:')
    cm_gbt = confusion_matrix(ytest, ypred)

    plt.figure(figsize=(9,9))
    sns.heatmap(cm_gbt, annot=True, fmt=".0f", linewidths=.5, square = True, cmap = 'Blues_r');
    plt.ylabel('Actual label')
    plt.show();

# %% [markdown]
# # 5. Entrenamiento de modelos
#
# ### En los proximos 4 bloques entreno los modelos y genero los reports de métricas
#
# El primer bloque captará el modelo base (decisión al azar).

# %%
print('The model presented is: Random Values')
print('')


randomlist = []
for i in range(0,len(ytest)):
    n = random.randint(0,1)
    randomlist.append(n)


print('')
evaluate_model(ytest=ytest, ypred=randomlist, ypred_proba = None)
print('')
# Out:
# The model presented is: Random Values
#
#
#
# Accuracy of the model: 0.5010406484945138
#
# F-Score: 0.03215
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.50      0.66   1337798
#            1       0.02      0.49      0.03     22892
#
#     accuracy                           0.50   1360690
#    macro avg       0.50      0.50      0.35   1360690
# weighted avg       0.97      0.50      0.65   1360690
#
#
# Confusion matrix:

# %% [markdown]
# ## Ahora genero los modelo de machine learning

# %%
classifiers = [
    LogisticRegression(n_jobs=-1),
    DecisionTreeClassifier(),
    RandomForestClassifier(n_jobs=-1, random_state=158),
    AdaBoostClassifier(random_state=158),
    GradientBoostingClassifier(random_state=158),
    #XGBClassifier(),
    LGBMClassifier(random_state=158, n_jobs=-1)
    ]

for classifier in classifiers:
       
    pipe = Pipeline(steps=[('classifier', classifier)])
    pipe.fit(xtrain, ytrain)   
    
    print('The model presented is:', classifier)
    print('')
    print("model score: %.3f" % pipe.score(xtest, ytest))
    
    ypred = pipe.predict(xtest)
    ypred_proba = pipe.predict_proba(xtest)      
    
    print('')
    evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
    print('')
        
    yhat = ypred_proba[:, 1]
    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # plot the roc curve for the model
    print('ROC Curve:')
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    
    filename  = '../models/' + re.sub(r"\([^()]*\)", '', str(classifier)) + '_personal_prob.pickle'
    pickle.dump(pipe['classifier'], open(filename, 'wb'))
    
    print('-----------------------------------------------------------')
# Out:
# The model presented is: LogisticRegression(n_jobs=-1)
#
# model score: 0.983
#
# ROC-AUC score of the model: 0.6176630528823108
#
# Accuracy of the model: 0.9831761826720267
#
# F-Score: 0.00000
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99   1337798
#            1       0.00      0.00      0.00     22892
#
#     accuracy                           0.98   1360690
#    macro avg       0.49      0.50      0.50   1360690
# weighted avg       0.97      0.98      0.97   1360690
#
#
# Confusion matrix:
# ROC Curve:
# -----------------------------------------------------------
# The model presented is: DecisionTreeClassifier()
#
# model score: 0.972
#
# ROC-AUC score of the model: 0.649663225026313
#
# Accuracy of the model: 0.9720252224974094
#
# F-Score: 0.27546
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99   1337798
# ...

# %% [markdown]
# **Los modelos siguientes necesitan ciertos ajustes a aplicar en el bucle, por lo tanto los entrenamos de forma separada.**

# %%
XGBClassifier_list = [
    #LogisticRegression(n_jobs=-1),
    #DecisionTreeClassifier(),
    #RandomForestClassifier(n_jobs=-1, random_state=158),
    #AdaBoostClassifier(random_state=158),
    #GradientBoostingClassifier(random_state=158),
    XGBClassifier()#,
    #LGBMClassifier(random_state=158, n_jobs=-1)
    ]

for classifier in XGBClassifier_list:
       
    pipe = Pipeline(steps=[('classifier', classifier)])
    pipe.fit(xtrain, ytrain)   
    
    print('The model presented is:', classifier)
    print('')
    print("model score: %.3f" % pipe.score(xtest, ytest))
    
    ypred = pipe.predict(xtest)
    ypred_proba = pipe.predict_proba(xtest)      
    
    print('')
    evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
    print('')
        
    yhat = ypred_proba[:, 1]
    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # plot the roc curve for the model
    print('ROC Curve:')
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    
    filename  = '../models/' + 'XGBClassifier_personal_prob' + '.pickle'
    pickle.dump(pipe['classifier'], open(filename, 'wb'))
    
    print('-----------------------------------------------------------')
# Out:
# [19:55:35] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The model presented is: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
#
# model score: 0.984
#
# ...

# %%
CBClassifier_list = [
    #LogisticRegression(n_jobs=-1),
    #DecisionTreeClassifier(),
    #RandomForestClassifier(n_jobs=-1, random_state=158),
    #AdaBoostClassifier(random_state=158),
    #GradientBoostingClassifier(random_state=158),
    #XGBClassifier()#,
    #LGBMClassifier(random_state=158, n_jobs=-1)
    CatBoostClassifier()
    ]

for classifier in CBClassifier_list:
       
    pipe = Pipeline(steps=[('classifier', classifier)])
    pipe.fit(xtrain, ytrain)   
    
    print('The model presented is:', classifier)
    print('')
    print("model score: %.3f" % pipe.score(xtest, ytest))
    
    ypred = pipe.predict(xtest)
    ypred_proba = pipe.predict_proba(xtest)      
    
    print('')
    evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
    print('')
        
    yhat = ypred_proba[:, 1]
    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # plot the roc curve for the model
    print('ROC Curve:')
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    
    filename  = '../models/' + 'CatBoostClassifier_personal_prob' + '.pickle'
    pickle.dump(pipe['classifier'], open(filename, 'wb'))
    
    print('-----------------------------------------------------------')
# Out:
# Learning rate set to 0.358722
# 0:	learn: 0.2155414	total: 653ms	remaining: 10m 52s
# 1:	learn: 0.1136364	total: 1.19s	remaining: 9m 51s
# 2:	learn: 0.0878858	total: 1.7s	remaining: 9m 26s
# 3:	learn: 0.0794215	total: 2.2s	remaining: 9m 7s
# 4:	learn: 0.0757834	total: 2.67s	remaining: 8m 51s
# 5:	learn: 0.0738535	total: 3.2s	remaining: 8m 50s
# 6:	learn: 0.0733920	total: 3.75s	remaining: 8m 51s
# 7:	learn: 0.0729899	total: 4.27s	remaining: 8m 49s
# 8:	learn: 0.0726831	total: 4.8s	remaining: 8m 48s
# 9:	learn: 0.0724398	total: 5.31s	remaining: 8m 45s
# 10:	learn: 0.0720491	total: 5.8s	remaining: 8m 41s
# 11:	learn: 0.0719395	total: 6.34s	remaining: 8m 41s
# 12:	learn: 0.0717719	total: 6.87s	remaining: 8m 41s
# 13:	learn: 0.0715695	total: 7.42s	remaining: 8m 42s
# 14:	learn: 0.0714806	total: 7.96s	remaining: 8m 42s
# 15:	learn: 0.0713793	total: 8.47s	remaining: 8m 41s
# 16:	learn: 0.0713058	total: 9.01s	remaining: 8m 40s
# 17:	learn: 0.0711577	total: 9.54s	remaining: 8m 40s
# ...

# %% [markdown]
# # 6. Selección del mejor modelo
#
# Considero que el modelo ganador en este punto es el RandomForest. Si bien la matriz de confusión es mejor en el Árbol de Desición, considero que la forma de la curva de ROC es mucho mejor en el RandomForest y esto más que compensa el menor desempeño clasificatiorio a priori.
#
# Además, un modelo RandomForest esta formado internamente por múltiples Árboles, con lo cual, podríamos obtener valores muy similares ajustando los hiperparámetros.
#
# # 7. Importo los modelos entrenados anteriormente
#
# Esto es para realizar nuevas métricas como es la matriz de confusión normalizada. Esto nos permitirá obtener una mejor precisión en la determinación del mejor modelo.
#
# #### El cambio más importante para realizar la evaluación es que se toma el threshold óptimo para cada clasificador, con lo cual es una comparación más objetiva.

# %%
model_list = ['LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier',
               'AdaBoostClassifier', 'GradientBoostingClassifier', 'XGBClassifier', 'LGBMClassifier']

# %%
unpickeled_models = []
for model in list(model_list):
    ''' use after the model is pickled '''
    classifier_f = open('../models/'+ model +'_personal_prob.pickle',"rb")
    unpickeled_models.append(pickle.load(classifier_f))
    classifier_f.close()

# %%
unpickeled_models
# Out:
# [LogisticRegression(n_jobs=-1),
#  DecisionTreeClassifier(),
#  RandomForestClassifier(n_jobs=-1, random_state=158),
#  AdaBoostClassifier(random_state=158),
#  GradientBoostingClassifier(random_state=158),
#  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#                gamma=0, gpu_id=-1, importance_type=None,
#                interaction_constraints='', learning_rate=0.300000012,
#                max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#                monotone_constraints='()', n_estimators=100, n_jobs=8,
#                num_parallel_tree=1, predictor='auto', random_state=0,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#                tree_method='exact', validate_parameters=1, verbosity=None),
#  LGBMClassifier(random_state=158)]

# %%
for i in unpickeled_models:
    print('The model is:', i)
    print('')
    ypred_proba = i.predict_proba(xtest)    
    prob_predictions = i.predict_proba(xtest)
    yhat = ypred_proba[:, 1]
    # calculate optimized threshold
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # calculate the g-mean for each threshold
    gmeans = np.sqrt(tpr * (1-fpr))
    # locate the index of the largest g-mean
    ix = np.argmax(gmeans)
    y_pred_best = (i.predict_proba(xtest)[:,1] >= thresholds[ix]).astype(bool)
    evaluate_model(ypred=y_pred_best, ytest=ytest)
    print('')
    # plot the roc curve for the model
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    plt.scatter(fpr[ix], tpr[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    print('Confusion matrix normalized:')
    cm_gbt = confusion_matrix(ytest, y_pred_best, normalize='true')
    print('')
    plt.figure(figsize=(9,9))
    sns.heatmap(cm_gbt, annot=True, fmt='.5f', linewidths=.5, square = True, cmap = 'Blues_r');
    plt.ylabel('Actual label')
    plt.show();
    print('')
    # calculate pr-curve
    precision, recall, thresholds = precision_recall_curve(ytest, yhat)
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    # plot the roc curve for the model
    no_skill = len(ytest[ytest==1]) / len(ytest)
    plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
    plt.plot(recall, precision, marker='.', label='Random Forest')
    plt.scatter(recall[ix], precision[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    skplt.metrics.plot_cumulative_gain(ytest, prob_predictions)
    plt.show();
    print('')
    skplt.metrics.plot_lift_curve(ytest, prob_predictions)
    plt.show();
    print('---------------------------------------------------------')
# Out:
# The model is: LogisticRegression(n_jobs=-1)
#
#
# Accuracy of the model: 0.6057360603811301
#
# F-Score: 0.04626
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.61      0.75   1337798
#            1       0.02      0.57      0.05     22892
#
#     accuracy                           0.61   1360690
#    macro avg       0.51      0.59      0.40   1360690
# weighted avg       0.97      0.61      0.74   1360690
#
#
# Confusion matrix:
# Confusion matrix normalized:
# Best Threshold=0.078885, F-Score=nan
# ---------------------------------------------------------
# The model is: DecisionTreeClassifier()
#
#
# Accuracy of the model: 0.9720252224974094
#
# F-Score: 0.27546
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99   1337798
#            1       0.24      0.32      0.28     22892
#
# ...

# %% [markdown]
# ### Nuevamente y de manera más directa, el modelo óptimo es el RandomForest

# %% [markdown]
# # 8. Optimización de hiperparámetros del modelo ganador: RandomForest

# %%
model = RandomForestClassifier()

param_grid = { 
    'n_estimators': [200], #, 500],
    'max_features': ['auto', 'sqrt'], #, 'log2'],
    'max_depth' : [6,7], #,6,7,8],
    'criterion' : ['gini', 'entropy']
}
    

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    n_jobs = -1,
    cv = 2,
    verbose=4
)

# %%
grid_search.fit(xtrain, ytrain)
# Out:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# GridSearchCV(cv=2, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [6, 7],
#                          'max_features': ['auto', 'sqrt'],
#                          'n_estimators': [200]},
#              verbose=4)

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=7, n_estimators=200)

# %%
pipe = Pipeline(steps=[('classifier', grid_search.best_estimator_)])

#pipe.fit(xtrain, ytrain)   

print('The model presented is:', pipe['classifier'])
print('')
print("model score: %.3f" % pipe.score(xtest, ytest))

ypred = pipe.predict(xtest)
ypred_proba = pipe.predict_proba(xtest)      

print('')
evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
print('')

yhat = ypred_proba[:, 1]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(ytest, yhat)
# plot the roc curve for the model
print('ROC Curve:')
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
# show the plot
plt.show();

filename  = '../models/' + 'grid_search' + '.pickle'
pickle.dump(pipe['classifier'], open(filename, 'wb'))

print('-----------------------------------------------------------')
# Out:
# The model presented is: RandomForestClassifier(max_depth=7, n_estimators=200)
#
# model score: 0.983
#
# ROC-AUC score of the model: 0.8071305700644897
#
# Accuracy of the model: 0.9832776018049666
#
# F-Score: 0.01198
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99   1337798
#            1       1.00      0.01      0.01     22892
#
#     accuracy                           0.98   1360690
#    macro avg       0.99      0.50      0.50   1360690
# weighted avg       0.98      0.98      0.98   1360690
#
#
# Confusion matrix:
# ROC Curve:
# -----------------------------------------------------------

# %% [markdown]
# ## Importo nuevamente el modelo ya que quiero realizar el informe con el punto de corte óptimo

# %%
grid_search_model = []
for model in ['grid_search']:
    ''' use after the model is pickled '''
    classifier_f = open('../models/'+ 'grid_search' +'.pickle',"rb")
    grid_search_model.append(pickle.load(classifier_f))
    classifier_f.close()

for i in list(grid_search_model):
    print('The model is:', i)
    print('')
    ypred_proba = i.predict_proba(xtest)    
    prob_predictions = i.predict_proba(xtest)
    yhat = ypred_proba[:, 1]
    # calculate optimized threshold
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # calculate the g-mean for each threshold
    gmeans = np.sqrt(tpr * (1-fpr))
    # locate the index of the largest g-mean
    ix = np.argmax(gmeans)
    y_pred_best = (i.predict_proba(xtest)[:,1] >= thresholds[ix]).astype(bool)
    evaluate_model(ypred=y_pred_best, ytest=ytest)
    print('')
    # plot the roc curve for the model
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    plt.scatter(fpr[ix], tpr[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    print('Confusion matrix normalized:')
    cm_gbt = confusion_matrix(ytest, y_pred_best, normalize='true')
    print('')
    plt.figure(figsize=(9,9))
    sns.heatmap(cm_gbt, annot=True, fmt='.5f', linewidths=.5, square = True, cmap = 'Blues_r');
    plt.ylabel('Actual label')
    plt.show();
    print('')
    # calculate pr-curve
    precision, recall, thresholds = precision_recall_curve(ytest, yhat)
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    # plot the roc curve for the model
    no_skill = len(ytest[ytest==1]) / len(ytest)
    plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
    plt.plot(recall, precision, marker='.', label='Random Forest')
    plt.scatter(recall[ix], precision[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    skplt.metrics.plot_cumulative_gain(ytest, prob_predictions)
    plt.show();
    print('')
    skplt.metrics.plot_lift_curve(ytest, prob_predictions)
    plt.show();
    print('---------------------------------------------------------')
# Out:
# The model is: RandomForestClassifier(max_depth=7, n_estimators=200)
#
#
# Accuracy of the model: 0.7631223864362934
#
# F-Score: 0.08964
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.76      0.86   1337798
#            1       0.05      0.69      0.09     22892
#
#     accuracy                           0.76   1360690
#    macro avg       0.52      0.73      0.48   1360690
# weighted avg       0.98      0.76      0.85   1360690
#
#
# Confusion matrix:
# Confusion matrix normalized:
# Best Threshold=0.078103, F-Score=0.200
# ---------------------------------------------------------

# %% [markdown]
# ## Observaciones
#
# El modelo empeoró, quizás deberíamos modificar los valores del GridSearch.
#
# En lugar de realizar este paso, vamos a realizar un Upsampling de las observaciones de fallecidos, para dotar al algoritmo de mayor cantidad de fallecidos y así lograr una mayor generalización sobre ellos.

# %% [markdown]
# # 9. Generamos un Upsampling con SMOTE y reentrenamos los modelos
#
# Verificamos si esta práctica mejora al modelo ganador RandomForest.

# %%
# transform the dataset
oversample = SMOTE(random_state=1238, n_jobs=-1, sampling_strategy=0.2)
xtrain2, ytrain2 = oversample.fit_resample(xtrain, ytrain)

# %%
ytrain2.value_counts()/len(ytrain2)
# Out:
# 0    0.833333
# 1    0.166667
# Name: C_SEV, dtype: float64

# %% [markdown]
# ## Entrenamiento y primeros resutados

# %%
classifiers = [
    LogisticRegression(n_jobs=-1),
    DecisionTreeClassifier(),
    RandomForestClassifier(n_jobs=-1, random_state=158),
    AdaBoostClassifier(random_state=158),
    GradientBoostingClassifier(random_state=158),
    #XGBClassifier(),
    LGBMClassifier(random_state=158, n_jobs=-1)
    ]

for classifier in classifiers:
       
    pipe = Pipeline(steps=[('classifier', classifier)])
    pipe.fit(xtrain, ytrain)   
    
    print('The model presented is:', classifier)
    print('')
    print("model score: %.3f" % pipe.score(xtest, ytest))
    
    ypred = pipe.predict(xtest)
    ypred_proba = pipe.predict_proba(xtest)      
    
    print('')
    evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
    print('')
        
    yhat = ypred_proba[:, 1]
    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # plot the roc curve for the model
    print('ROC Curve:')
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    
    filename  = '../models/' + re.sub(r"\([^()]*\)", '', str(classifier)) + '_personal_prob_smote.pickle'
    pickle.dump(pipe['classifier'], open(filename, 'wb'))
    
    print('-----------------------------------------------------------')
# Out:
# The model presented is: LogisticRegression(n_jobs=-1)
#
# model score: 0.983
#
# ROC-AUC score of the model: 0.6176630528823108
#
# Accuracy of the model: 0.9831761826720267
#
# F-Score: 0.00000
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99   1337798
#            1       0.00      0.00      0.00     22892
#
#     accuracy                           0.98   1360690
#    macro avg       0.49      0.50      0.50   1360690
# weighted avg       0.97      0.98      0.97   1360690
#
#
# Confusion matrix:
# ROC Curve:
# -----------------------------------------------------------
# The model presented is: DecisionTreeClassifier()
#
# model score: 0.972
#
# ROC-AUC score of the model: 0.6505251464462163
#
# Accuracy of the model: 0.9719480557658247
#
# F-Score: 0.27607
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99   1337798
# ...

# %% [markdown]
# ## Entrenamiento y resultados de los modelos restantes

# %%
XGBClassifier_list = [
    #LogisticRegression(n_jobs=-1),
    #DecisionTreeClassifier(),
    #RandomForestClassifier(n_jobs=-1, random_state=158),
    #AdaBoostClassifier(random_state=158),
    #GradientBoostingClassifier(random_state=158),
    XGBClassifier()#,
    #LGBMClassifier(random_state=158, n_jobs=-1)
    ]

for classifier in XGBClassifier_list:
       
    pipe = Pipeline(steps=[('classifier', classifier)])
    pipe.fit(xtrain, ytrain)   
    
    print('The model presented is:', classifier)
    print('')
    print("model score: %.3f" % pipe.score(xtest, ytest))
    
    ypred = pipe.predict(xtest)
    ypred_proba = pipe.predict_proba(xtest)      
    
    print('')
    evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
    print('')
        
    yhat = ypred_proba[:, 1]
    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # plot the roc curve for the model
    print('ROC Curve:')
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    
    filename  = '../models/' + 'XGBClassifier_personal_prob_smote' + '.pickle'
    pickle.dump(pipe['classifier'], open(filename, 'wb'))
    
    print('-----------------------------------------------------------')
# Out:
# [17:32:43] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The model presented is: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
#
# model score: 0.984
#
# ...

# %%
CBClassifier_list = [
    #LogisticRegression(n_jobs=-1),
    #DecisionTreeClassifier(),
    #RandomForestClassifier(n_jobs=-1, random_state=158),
    #AdaBoostClassifier(random_state=158),
    #GradientBoostingClassifier(random_state=158),
    #XGBClassifier()#,
    #LGBMClassifier(random_state=158, n_jobs=-1)
    CatBoostClassifier()
    ]

for classifier in CBClassifier_list:
       
    pipe = Pipeline(steps=[('classifier', classifier)])
    pipe.fit(xtrain, ytrain)   
    
    print('The model presented is:', classifier)
    print('')
    print("model score: %.3f" % pipe.score(xtest, ytest))
    
    ypred = pipe.predict(xtest)
    ypred_proba = pipe.predict_proba(xtest)      
    
    print('')
    evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
    print('')
        
    yhat = ypred_proba[:, 1]
    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # plot the roc curve for the model
    print('ROC Curve:')
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    
    filename  = '../models/' + 'CatBoostClassifier_personal_prob_smote' + '.pickle'
    pickle.dump(pipe['classifier'], open(filename, 'wb'))
    
    print('-----------------------------------------------------------')
# Out:
# Learning rate set to 0.358722
# 0:	learn: 0.2155414	total: 734ms	remaining: 12m 13s
# 1:	learn: 0.1136364	total: 1.33s	remaining: 11m 5s
# 2:	learn: 0.0878858	total: 1.95s	remaining: 10m 49s
# 3:	learn: 0.0794215	total: 2.54s	remaining: 10m 33s
# 4:	learn: 0.0757834	total: 3.1s	remaining: 10m 17s
# 5:	learn: 0.0738535	total: 3.74s	remaining: 10m 19s
# 6:	learn: 0.0733920	total: 4.36s	remaining: 10m 19s
# 7:	learn: 0.0729899	total: 4.98s	remaining: 10m 17s
# 8:	learn: 0.0726831	total: 5.64s	remaining: 10m 20s
# 9:	learn: 0.0724398	total: 6.24s	remaining: 10m 17s
# 10:	learn: 0.0720491	total: 6.83s	remaining: 10m 14s
# 11:	learn: 0.0719395	total: 7.46s	remaining: 10m 14s
# 12:	learn: 0.0717719	total: 8.09s	remaining: 10m 14s
# 13:	learn: 0.0715695	total: 8.75s	remaining: 10m 16s
# 14:	learn: 0.0714806	total: 9.39s	remaining: 10m 16s
# 15:	learn: 0.0713793	total: 9.99s	remaining: 10m 14s
# 16:	learn: 0.0713058	total: 10.6s	remaining: 10m 14s
# ...

# %% [markdown]
# ## Importo nuevamente el modelo ya que quiero realizar el informe con el punto de corte óptimo

# %%
smote_models = ['LogisticRegression_personal_prob_smote', 'DecisionTreeClassifier_personal_prob_smote',
 'RandomForestClassifier_personal_prob_smote', 'AdaBoostClassifier_personal_prob_smote',
 'GradientBoostingClassifier_personal_prob_smote', 'XGBClassifier_personal_prob_smote',
 'LGBMClassifier_personal_prob_smote', 'CatBoostClassifier_personal_prob_smote']

grid_search_model = []
for model in smote_models:
    ''' use after the model is pickled '''
    classifier_f = open('../models/'+ model +'.pickle',"rb")
    grid_search_model.append(pickle.load(classifier_f))
    classifier_f.close()
    
for i in grid_search_model:
    print('The model is:', i)
    print('')
    ypred_proba = i.predict_proba(xtest)    
    prob_predictions = i.predict_proba(xtest)
    yhat = ypred_proba[:, 1]
    # calculate optimized threshold
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # calculate the g-mean for each threshold
    gmeans = np.sqrt(tpr * (1-fpr))
    # locate the index of the largest g-mean
    ix = np.argmax(gmeans)
    y_pred_best = (i.predict_proba(xtest)[:,1] >= thresholds[ix]).astype(bool)
    evaluate_model(ypred=y_pred_best, ytest=ytest)
    print('')
    # plot the roc curve for the model
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    plt.scatter(fpr[ix], tpr[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    print('Confusion matrix normalized:')
    cm_gbt = confusion_matrix(ytest, y_pred_best, normalize='true')
    print('')
    plt.figure(figsize=(9,9))
    sns.heatmap(cm_gbt, annot=True, fmt='.5f', linewidths=.5, square = True, cmap = 'Blues_r');
    plt.ylabel('Actual label')
    plt.show();
    print('')
    # calculate pr-curve
    precision, recall, thresholds = precision_recall_curve(ytest, yhat)
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    # plot the roc curve for the model
    no_skill = len(ytest[ytest==1]) / len(ytest)
    plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
    plt.plot(recall, precision, marker='.', label='Random Forest')
    plt.scatter(recall[ix], precision[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    skplt.metrics.plot_cumulative_gain(ytest, prob_predictions)
    plt.show();
    print('')
    skplt.metrics.plot_lift_curve(ytest, prob_predictions)
    plt.show();
    print('---------------------------------------------------------')
# Out:
# The model is: LogisticRegression(n_jobs=-1)
#
#
# Accuracy of the model: 0.6057360603811301
#
# F-Score: 0.04626
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.61      0.75   1337798
#            1       0.02      0.57      0.05     22892
#
#     accuracy                           0.61   1360690
#    macro avg       0.51      0.59      0.40   1360690
# weighted avg       0.97      0.61      0.74   1360690
#
#
# Confusion matrix:
# Confusion matrix normalized:
# Best Threshold=0.078885, F-Score=nan
# ---------------------------------------------------------
# The model is: DecisionTreeClassifier()
#
#
# Accuracy of the model: 0.9719480557658247
#
# F-Score: 0.27607
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99   1337798
#            1       0.24      0.32      0.28     22892
#
# ...

# %% [markdown]
# # 10. Selección del modelo ganador
#
# ### El mejor modelo en este caso es el XGBoost ya que es el que mejor detecta a los casos fallecidos.
#
# # 11. Optimización de hiperparámetros del modelo ganador: XGBoost

# %%
model = XGBClassifier()
param_grid = {
    'n_estimators': [400, 700], # 1000],
    'max_depth': [15, 20], #,25],
    #'reg_alpha': [1.1, 1.2, 1.3],
    #'reg_lambda': [1.1, 1.2, 1.3],
    'scale_pos_weight':[7], #, 8],
    'eval_metric': ["aucpr"], #, 'logloss'],
    'max_delta_step': [0]#, 3, 5, 10]
    
}

grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    n_jobs = -1,
    cv = 2,
    verbose=3
)

# %%
grid_search.fit(xtrain2, ytrain2)
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# GridSearchCV(cv=2,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      enable_categorical=False, gamma=None,
#                                      gpu_id=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
#                                      max_depth=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
# ...

# %%
grid_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='aucpr', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=20, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=400, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=7, subsample=1,
#               tree_method='approx', validate_parameters=1, verbosity=None)

# %%
pipe = Pipeline(steps=[('classifier', grid_search.best_estimator_)])

#pipe.fit(xtrain, ytrain)   

print('The model presented is:', pipe['classifier'])
print('')
print("model score: %.3f" % pipe.score(xtest, ytest))

ypred = pipe.predict(xtest)
ypred_proba = pipe.predict_proba(xtest)      

print('')
evaluate_model(ytest=ytest, ypred=ypred, ypred_proba = ypred_proba)
print('')

yhat = ypred_proba[:, 1]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(ytest, yhat)
# plot the roc curve for the model
print('ROC Curve:')
plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
plt.plot(fpr, tpr, marker='.', label='Random Forest')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
# show the plot
plt.show();

filename  = '../models/' + 'grid_search_gb_smote' + '.pickle'
pickle.dump(pipe['classifier'], open(filename, 'wb'))

print('-----------------------------------------------------------')
# Out:
# The model presented is: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='aucpr', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=20, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=400, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=7, subsample=1,
#               tree_method='approx', validate_parameters=1, verbosity=None)
#
# model score: 0.987
#
# ROC-AUC score of the model: 0.9132021410417386
#
# Accuracy of the model: 0.9874284370429709
#
# F-Score: 0.45747
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99   1337798
# ...

# %% [markdown]
# ## Importo nuevamente el modelo ya que quiero realizar el informe con el punto de corte óptimo

# %%
model_list = ['grid_search_gb_smote' ]

# %%
best_model_grid = []
for model in model_list:
    ''' use after the model is pickled '''
    if model == 'grid_search':
        classifier_f = open('../models/'+ model +'.pickle',"rb")
    elif model == 'grid_search_gb_smote':
        classifier_f = open('../models/'+ model +'.pickle',"rb")
    else:
        classifier_f = open('../models/'+ model +'_personal_prob.pickle',"rb")
    best_model_grid.append(pickle.load(classifier_f))
    classifier_f.close()

# %%
best_model_grid
# Out:
# [XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#                eval_metric='aucpr', gamma=0, gpu_id=-1, importance_type=None,
#                interaction_constraints='', learning_rate=0.300000012,
#                max_delta_step=0, max_depth=20, min_child_weight=1, missing=nan,
#                monotone_constraints='()', n_estimators=400, n_jobs=8,
#                num_parallel_tree=1, predictor='auto', random_state=0,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=7, subsample=1,
#                tree_method='approx', validate_parameters=1, verbosity=None)]

# %%
for i in best_model_grid:
    print('The model is:', i)
    print('')
    ypred_proba = i.predict_proba(xtest)    
    prob_predictions = i.predict_proba(xtest)
    yhat = ypred_proba[:, 1]
    # calculate optimized threshold
    fpr, tpr, thresholds = roc_curve(ytest, yhat)
    # calculate the g-mean for each threshold
    gmeans = np.sqrt(tpr * (1-fpr))
    # locate the index of the largest g-mean
    ix = np.argmax(gmeans)
    y_pred_best = (i.predict_proba(xtest)[:,1] >= thresholds[ix]).astype(bool)
    evaluate_model(ypred=y_pred_best, ytest=ytest)
    print('')
    # plot the roc curve for the model
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='Random Forest')
    plt.scatter(fpr[ix], tpr[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    print('Confusion matrix normalized:')
    cm_gbt = confusion_matrix(ytest, y_pred_best, normalize='true')
    print('')
    plt.figure(figsize=(9,9))
    sns.heatmap(cm_gbt, annot=True, fmt='.5f', linewidths=.5, square = True, cmap = 'Blues_r');
    plt.ylabel('Actual label')
    plt.show();
    print('')
    # calculate pr-curve
    precision, recall, thresholds = precision_recall_curve(ytest, yhat)
    # convert to f score
    fscore = (2 * precision * recall) / (precision + recall)
    # locate the index of the largest f score
    ix = np.argmax(fscore)
    print('Best Threshold=%f, F-Score=%.3f' % (thresholds[ix], fscore[ix]))
    # plot the roc curve for the model
    no_skill = len(ytest[ytest==1]) / len(ytest)
    plt.plot([0,1], [no_skill,no_skill], linestyle='--', label='No Skill')
    plt.plot(recall, precision, marker='.', label='Random Forest')
    plt.scatter(recall[ix], precision[ix], s=100, marker='o', color='black', label='Best')
    # axis labels
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    # show the plot
    plt.show();
    print('')
    skplt.metrics.plot_cumulative_gain(ytest, prob_predictions)
    plt.show();
    print('')
    skplt.metrics.plot_lift_curve(ytest, prob_predictions)
    plt.show();
    print('---------------------------------------------------------')
# Out:
# The model is: XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='aucpr', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=20, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=400, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=7, subsample=1,
#               tree_method='approx', validate_parameters=1, verbosity=None)
#
#
# Accuracy of the model: 0.8613585754286428
#
# F-Score: 0.16256
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92   1337798
#            1       0.09      0.80      0.16     22892
#
# ...

# %%
thresholds[ix]
# Out:
# 0.10831398

# %% [markdown]
# ## 12. Conclusiones comparativas entre RandomForest y XGBoost
#
# #### Con el modelo XGBoost hemos logrado un modelo que obtiene mayor cantidad de fallecidos detectados en el test. Creemos que esto sobrecompensa la mayor proporción de falsos positivos, ya que es el objetivo primordial para la aseguradora.
#
# El siguiente paso es realizar un análisis sobre la interpretabilidad del modelo. Se realizará en un script final.

# %% [markdown]
# # 13. Verificación de resultados mediante funciones auxiliares

# %%
from aux_func import data_preprocess, predict_optimized

# %%
original_test = pd.read_csv("../data/Untransformed_test_data_personal_prob.csv",low_memory=False)
original_test.set_index(['Unnamed: 0'], inplace=True)
original_test.index.names = ['']

# %%
processed_test = data_preprocess(original_test)

# %%
y_processed_test = processed_test['C_SEV']
x_processed_test = processed_test.drop(columns=['C_SEV'])

# %%
results_pipe = predict_optimized(x_processed_test)

# %%
evaluate_model(ypred=results_pipe, ytest=y_processed_test)
# Out:
# Accuracy of the model: 0.8613585754286428
#
# F-Score: 0.16256
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92   1337798
#            1       0.09      0.80      0.16     22892
#
#     accuracy                           0.86   1360690
#    macro avg       0.54      0.83      0.54   1360690
# weighted avg       0.98      0.86      0.91   1360690
#
#
# Confusion matrix:

# %% [markdown]
# ### Las funciones auxiliares creadas generan los mismos resultados obtenidos, las utilizaremos en la puesta en producción
